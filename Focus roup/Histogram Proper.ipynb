# %%
#focus1
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
# %matplotlib inline
x=['Surprise','Anger','Sadness','Fear','Happiness']
y=[55.49,17.73,61.16,81.39,25.1]
#x_pos = [i for i, _ in enumerate(x)]
barlist=plt.bar(x, y)
barlist[0].set_color('yellow')
barlist[1].set_color('r')
barlist[2].set_color('b')
barlist[3].set_color('orange')
barlist[4].set_color('g')
#for i in range(len(x)):
        #plt.text(i,y[i],y[i])
 
plt.show()

# %%
x=['Anger','Depression','Fatigue','Vigour','Tension','Confusion']
y=[89.16258606,114.3690705,13.16292442,4.332625085,14.9961212,45.97667274]
#x_pos = [i for i, _ in enumerate(x)]
barlist=plt.bar(x, y)
barlist[0].set_color('r')
barlist[1].set_color('black')
barlist[2].set_color('b')
barlist[3].set_color('orange')
barlist[4].set_color('g')
barlist[5].set_color('pink')
#for i in range(len(x)):
        #plt.text(i,y[i],y[i])
 
plt.show()

# %%
#focus2
x=['Surprise','Anger','Sadness','Fear','Happiness']
y=[51.1,16.64,63.41,60.9,18.85]
#x_pos = [i for i, _ in enumerate(x)]
barlist=plt.bar(x, y)
barlist[0].set_color('yellow')
barlist[1].set_color('r')
barlist[2].set_color('b')
barlist[3].set_color('orange')
barlist[4].set_color('g')
#for i in range(len(x)):
        #plt.text(i,y[i],y[i])
 
plt.show()

# %%
x=['Anger','Depression','Fatigue','Vigour','Tension','Confusion']
y=[56.68527072,100.5582509,14.90708434,4.267424382,12.02382609,41.5581434]
#x_pos = [i for i, _ in enumerate(x)]
barlist=plt.bar(x, y)
barlist[0].set_color('r')
barlist[1].set_color('black')
barlist[2].set_color('b')
barlist[3].set_color('orange')
barlist[4].set_color('g')
barlist[5].set_color('pink')
#for i in range(len(x)):
        #plt.text(i,y[i],y[i])
 
plt.show()

# %%
#focus3
x=['Surprise','Anger','Sadness','Fear','Happiness']
y=[100.72,31.17,92.82,100.78,43.26]
#x_pos = [i for i, _ in enumerate(x)]
barlist=plt.bar(x, y)
barlist[0].set_color('yellow')
barlist[1].set_color('r')
barlist[2].set_color('b')
barlist[3].set_color('orange')
barlist[4].set_color('g')
#for i in range(len(x)):
        #plt.text(i,y[i],y[i])
 
plt.show()

# %%
x=['Anger','Depression','Fatigue','Vigour','Tension','Confusion']
y=[122.4444804,199.0780195,27.23501534,7.070292619,24.63772157,75.53447093]
#x_pos = [i for i, _ in enumerate(x)]
barlist=plt.bar(x, y)
barlist[0].set_color('r')
barlist[1].set_color('black')
barlist[2].set_color('b')
barlist[3].set_color('orange')
barlist[4].set_color('g')
barlist[5].set_color('pink')
#for i in range(len(x)):
        #plt.text(i,y[i],y[i])
 
plt.show()

# %%
#focus1 poms 3m-3f
x=['Anger','Depression','Fatigue','Vigour','Tension','Confusion']
y1=[53.090681,67.76034553,7.197155714,3.641539031,8.722815008,24.58746401]
male = [((element/165) * 100) for element in y1]
y2=[36.07190585,46.60872397,5.965768923,0.691085978,6.273306259,21.38920875]
female = [((element/117) * 100) for element in y2]
X_axis = np.arange(len(x))
  
plt.bar(X_axis - 0.2, male, 0.4, label = 'Male',color='blue')
plt.bar(X_axis + 0.2, female, 0.4, label = 'Female',color='pink')
plt.xticks(X_axis, x)
plt.legend()
plt.show()

# %%
#focus2 poms 2m,6-f male-female by lines
x=['Anger','Depression','Fatigue','Vigour','Tension','Confusion']
y1=[0.322755924,0.390580631,0.050433886,0.006818463,0.077277801,0.152133291]
male = [element * 100 for element in y1]
y2=[0.240368176,0.440931334,0.065961071,0.019490661,0.050282182,0.182966574]
female = [element * 100 for element in y2]
X_axis = np.arange(len(x))
  
plt.bar(X_axis - 0.2, male, 0.4, label = 'Male',color='blue')
plt.bar(X_axis + 0.2, female, 0.4, label = 'Female',color='pink')
plt.xticks(X_axis, x)
plt.legend()
plt.show()

# %%
#focus3 poms 2m,4f
x=['Anger','Depression','Fatigue','Vigour','Tension','Confusion']
y1=[21.44110537,28.67660068,2.617934187,1.0909923,4.174092089,18.99927559]
male = [((element/77) * 100) for element in y1]
y2=[101.0033749,170.4014185,24.61708083,5.979299685,20.4636298,56.53519655]
female = [((element/379) * 100) for element in y2]
X_axis = np.arange(len(x))
  
plt.bar(X_axis - 0.2, male, 0.4, label = 'Male',color='blue')
plt.bar(X_axis + 0.2, female, 0.4, label = 'Female',color='pink')
plt.xticks(X_axis, x)
plt.legend()
plt.show()

# %%
#focus1 text2emo

x=['Surprise','Anger','Sadness','Fear','Happiness']
y1=[30.77,11.63,37.14,45,17.41]
male = [((element/165) * 100) for element in y1]
y2=[24.72,6.1,24.02,36.39,7.69]
female = [((element/117) * 100) for element in y2]
X_axis = np.arange(len(x))
  
plt.bar(X_axis - 0.2, male, 0.4, label = 'Male',color='blue')
plt.bar(X_axis + 0.2, female, 0.4, label = 'Female',color='pink')
plt.xticks(X_axis, x)
plt.legend()
plt.show()

# %%
#focus2 text2emo

x=['Surprise','Anger','Sadness','Fear','Happiness']
y1=[1.3,0.45,6.12,5.18,0.95]
male = [((element/17) * 100) for element in y1]
y2=[49.8,16.19,57.29,55.72,17.9]
female = [((element/213) * 100) for element in y2]
X_axis = np.arange(len(x))
  
plt.bar(X_axis - 0.2, male, 0.4, label = 'Male',color='blue')
plt.bar(X_axis + 0.2, female, 0.4, label = 'Female',color='pink')
plt.xticks(X_axis, x)
plt.legend()
plt.show()

# %%
#focus3 text2emo

x=['Surprise','Anger','Sadness','Fear','Happiness']
y1=[13.24,5.54,14.19,15.58,8.46]
male = [((element/77) * 100) for element in y1]
y2=[87.48,25.63,78.63,85.2,34.8]
female = [((element/379) * 100) for element in y2]
X_axis = np.arange(len(x))
  
plt.bar(X_axis - 0.2, male, 0.4, label = 'Male',color='blue')
plt.bar(X_axis + 0.2, female, 0.4, label = 'Female',color='pink')
plt.xticks(X_axis, x)
plt.legend()
plt.show()
